# %%
import requests
from resources import functs
import time

resp = requests.get('https://api.agify.io/',\
    headers = {'content-type':'application/json'}, \
    params = {'name':'john',
            'dnt': 1},
        )
print(resp.text)
# Out:
# {"age":72,"count":277407,"name":"john"}

# %%
resp.headers
# Out:
# {'Server': 'nginx/1.16.1', 'Date': 'Fri, 24 Feb 2023 08:37:34 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '39', 'Connection': 'keep-alive', 'access-control-allow-credentials': 'true', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'x-rate-limit-limit,x-rate-limit-remaining,x-rate-limit-reset', 'cache-control': 'max-age=0, private, must-revalidate', 'x-rate-limit-limit': '1000', 'x-rate-limit-remaining': '988', 'x-rate-limit-reset': '55346', 'x-request-id': 'F0a12NOu6ZB5bcIKExvR'}

# %%
resp.status_code
# Out:
# 200
